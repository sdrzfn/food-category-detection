# %%
# Instalasi bing-image-downloader
# %pip install bing-image-downloader
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Buat train_set directory
# %mkdir train_set

# %%
from bing_image_downloader import downloader

downloader.download('roti', limit=200, output_dir='train_set', adult_filter_off=True)
# Out:
# [%] Downloading Images to c:\Users\sadrakhzp\Documents\SADRAKH\Peduli Pangan\Samsung Solve\food-mini-dataset\train_set\roti
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 25 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://smaakmenutie.nl/wp-content/uploads/2018/09/Surinaamse-roti-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://1.bp.blogspot.com/-fcIMz5wkIMg/U9V-dQzh6JI/AAAAAAAAGNc/niqfg6OqaQ8/s1600/Roti.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.simplyrecipes.com/thmb/3QALSvYU7u6ErRz0mQf9LfpTx4M=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/Simply-Recipes-Roti-LEAD-1-f3256a549133427e9e0e79fb5ee3d2f8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://recipeland.com/images/r/18336/511c693aac4ca94e4cf8_1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cookingorgeous.com/wp-content/uploads/2023/06/easy-guyanese-oil-roti-recipe-24-1024x683.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader

downloader.download('apem', limit=200, output_dir='train_set', adult_filter_off=True)
# Out:
# [%] Downloading Images to c:\Users\sadrakhzp\Documents\SADRAKH\Peduli Pangan\Samsung Solve\food-mini-dataset\train_set\apem
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/de/cb/19/decb1943d3bb8eb0e311141c0cde28e3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn-brilio-net.akamaized.net/news/2020/10/23/194349/1338845-1000xauto-resep-apem-kue-tradisional.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://resepkoki.id/wp-content/uploads/2020/01/Resep-Apem-Kukus-953x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://resepkoki.id/wp-content/uploads/2016/03/Resep-Apem-Panggang.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://superapp.id/blog/wp-content/uploads/2022/11/IDN-Times.jpg
# [%] File Downloaded !
#
# ...
